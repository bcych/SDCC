# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Test_Notebook
# This is a test notebook for the single domain comprehensive calculator

# %%
TMx = 0 
alignment = 'hard'
PRO = 1.00
OBL = 1.00

# %%
from sdcc.plotting import plot_energy_surface
plot_energy_surface(TMx,alignment,PRO,OBL);
